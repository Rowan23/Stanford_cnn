# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for the bonus section.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
##print("dbg1",type(X_train),X_train.shape)
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength
import time
from cs231n.classifiers.linear_classifier import LinearSVM

#learning_rates = [0.7e-10,0.7e-9, 0.7e-8, 0.7e-7,0.7e-6,0.7e-5,0.7e-4]
#regularization_strengths = [2e2,2e3,2e4, 2e5, 2e6,2e7,2e8]

learning_rates = [0.2e-6,0.4e-6, 0.6e-6, 0.8e-6,1.2e-6,2.5e-6,4e-6]
regularization_strengths = [0.7e4,0.9e4,1.1e4, 1.5e4, 2e4,3.5e4,0.4e4]

results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
for l_rate in learning_rates:
  for r_strength in regularization_strengths:
    svm = LinearSVM()
    tic = time.time()
    loss_hist = svm.train(X_train_feats, y_train, learning_rate=l_rate, reg=r_strength,
                      num_iters=1500, verbose=True)
    toc = time.time()
    print('That took %fs' % (toc - tic))
    y_train_pred = svm.predict(X_train_feats)
    train_acc = np.mean(y_train == y_train_pred)
    print('training accuracy: %f' % train_acc)
    y_val_pred = svm.predict(X_val_feats)
    val_acc = np.mean(y_val == y_val_pred)
    print('validation accuracy: %f' % val_acc)
    results[l_rate,r_strength] = [train_acc,val_acc]
    if val_acc>best_val:
      best_val = val_acc
      best_svm = svm
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 1500: loss 19.626882
# iteration 100 / 1500: loss 15.064699
# iteration 200 / 1500: loss 12.457921
# iteration 300 / 1500: loss 10.981013
# iteration 400 / 1500: loss 10.122931
# iteration 500 / 1500: loss 9.640465
# iteration 600 / 1500: loss 9.365911
# iteration 700 / 1500: loss 9.208227
# iteration 800 / 1500: loss 9.116178
# iteration 900 / 1500: loss 9.065367
# iteration 1000 / 1500: loss 9.036830
# iteration 1100 / 1500: loss 9.019981
# iteration 1200 / 1500: loss 9.010014
# iteration 1300 / 1500: loss 9.004620
# iteration 1400 / 1500: loss 9.001157
# That took 1.139904s
# training accuracy: 0.375306
# validation accuracy: 0.361000
# iteration 0 / 1500: loss 23.089849
# iteration 100 / 1500: loss 15.839671
# iteration 200 / 1500: loss 12.316555
# iteration 300 / 1500: loss 10.612790
# iteration 400 / 1500: loss 9.781381
# iteration 500 / 1500: loss 9.381599
# iteration 600 / 1500: loss 9.185705
# iteration 700 / 1500: loss 9.088580
# iteration 800 / 1500: loss 9.041990
# iteration 900 / 1500: loss 9.018917
# iteration 1000 / 1500: loss 9.007849
# iteration 1100 / 1500: loss 9.002875
# iteration 1200 / 1500: loss 9.000886
# iteration 1300 / 1500: loss 8.999453
# iteration 1400 / 1500: loss 8.998464
# That took 1.018813s
# training accuracy: 0.402592
# validation accuracy: 0.375000
# iteration 0 / 1500: loss 25.389325
# iteration 100 / 1500: loss 15.780143
# iteration 200 / 1500: loss 11.813695
# iteration 300 / 1500: loss 10.160682
# iteration 400 / 1500: loss 9.477550
# iteration 500 / 1500: loss 9.197464
# iteration 600 / 1500: loss 9.081411
# iteration 700 / 1500: loss 9.032179
# iteration 800 / 1500: loss 9.012582
# iteration 900 / 1500: loss 9.004317
# iteration 1000 / 1500: loss 9.000793
# iteration 1100 / 1500: loss 8.999221
# iteration 1200 / 1500: loss 8.998844
# iteration 1300 / 1500: loss 8.998650
# iteration 1400 / 1500: loss 8.998487
# That took 0.797619s
# training accuracy: 0.414327
# validation accuracy: 0.406000
# iteration 0 / 1500: loss 33.037908
# iteration 100 / 1500: loss 16.208237
# iteration 200 / 1500: loss 11.164053
# iteration 300 / 1500: loss 9.647786
# iteration 400 / 1500: loss 9.194273
# iteration 500 / 1500: loss 9.057631
# iteration 600 / 1500: loss 9.016317
# iteration 700 / 1500: loss 9.004226
# iteration 800 / 1500: loss 9.000472
# iteration 900 / 1500: loss 8.999238
# iteration 1000 / 1500: loss 8.998902
# iteration 1100 / 1500: loss 8.999013
# iteration 1200 / 1500: loss 8.998841
# iteration 1300 / 1500: loss 8.998904
# iteration 1400 / 1500: loss 8.998585
# That took 0.846209s
# training accuracy: 0.416245
# validation accuracy: 0.422000
# iteration 0 / 1500: loss 39.281110
# iteration 100 / 1500: loss 15.070536
# iteration 200 / 1500: loss 10.219391
# iteration 300 / 1500: loss 9.243152
# iteration 400 / 1500: loss 9.048129
# iteration 500 / 1500: loss 9.009062
# iteration 600 / 1500: loss 9.001120
# iteration 700 / 1500: loss 8.999330
# iteration 800 / 1500: loss 8.999148
# iteration 900 / 1500: loss 8.999132
# iteration 1000 / 1500: loss 8.999149
# iteration 1100 / 1500: loss 8.999208
# iteration 1200 / 1500: loss 8.999083
# iteration 1300 / 1500: loss 8.999046
# iteration 1400 / 1500: loss 8.998966
# That took 0.774402s
# training accuracy: 0.413306
# validation accuracy: 0.415000
# iteration 0 / 1500: loss 62.528595
# iteration 100 / 1500: loss 12.191028
# iteration 200 / 1500: loss 9.190164
# iteration 300 / 1500: loss 9.010718
# iteration 400 / 1500: loss 9.000121
# iteration 500 / 1500: loss 8.999593
# iteration 600 / 1500: loss 8.999510
# iteration 700 / 1500: loss 8.999536
# iteration 800 / 1500: loss 8.999468
# iteration 900 / 1500: loss 8.999525
# iteration 1000 / 1500: loss 8.999629
# iteration 1100 / 1500: loss 8.999492
# iteration 1200 / 1500: loss 8.999494
# iteration 1300 / 1500: loss 8.999494
# iteration 1400 / 1500: loss 8.999497
# That took 1.008840s
# training accuracy: 0.412898
# validation accuracy: 0.422000
# iteration 0 / 1500: loss 15.044812
# iteration 100 / 1500: loss 13.394797
# iteration 200 / 1500: loss 12.180710
# iteration 300 / 1500: loss 11.315546
# iteration 400 / 1500: loss 10.670947
# iteration 500 / 1500: loss 10.210608
# iteration 600 / 1500: loss 9.877396
# iteration 700 / 1500: loss 9.634286
# iteration 800 / 1500: loss 9.461875
# iteration 900 / 1500: loss 9.336860
# iteration 1000 / 1500: loss 9.241069
# iteration 1100 / 1500: loss 9.171861
# iteration 1200 / 1500: loss 9.123409
# iteration 1300 / 1500: loss 9.090155
# iteration 1400 / 1500: loss 9.062549
# That took 1.107904s
# training accuracy: 0.212286
# validation accuracy: 0.223000
# iteration 0 / 1500: loss 19.804718
# iteration 100 / 1500: loss 12.514027
# iteration 200 / 1500: loss 10.142578
# iteration 300 / 1500: loss 9.370346
# iteration 400 / 1500: loss 9.119028
# iteration 500 / 1500: loss 9.036620
# iteration 600 / 1500: loss 9.010532
# iteration 700 / 1500: loss 9.001183
# iteration 800 / 1500: loss 8.998434
# iteration 900 / 1500: loss 8.997769
# iteration 1000 / 1500: loss 8.997540
# iteration 1100 / 1500: loss 8.997062
# iteration 1200 / 1500: loss 8.997317
# iteration 1300 / 1500: loss 8.997860
# iteration 1400 / 1500: loss 8.997336
# That took 1.080405s
# training accuracy: 0.412776
# validation accuracy: 0.421000
# iteration 0 / 1500: loss 22.521044
# iteration 100 / 1500: loss 12.183845
# iteration 200 / 1500: loss 9.750035
# iteration 300 / 1500: loss 9.173791
# iteration 400 / 1500: loss 9.040878
# iteration 500 / 1500: loss 9.007300
# iteration 600 / 1500: loss 9.000316
# iteration 700 / 1500: loss 8.998666
# iteration 800 / 1500: loss 8.998060
# iteration 900 / 1500: loss 8.998310
# iteration 1000 / 1500: loss 8.997553
# iteration 1100 / 1500: loss 8.998127
# iteration 1200 / 1500: loss 8.998170
# iteration 1300 / 1500: loss 8.997978
# iteration 1400 / 1500: loss 8.997897
# That took 1.114297s
# training accuracy: 0.410224
# validation accuracy: 0.407000
# iteration 0 / 1500: loss 25.036475
# iteration 100 / 1500: loss 11.732254
# iteration 200 / 1500: loss 9.464781
# iteration 300 / 1500: loss 9.077241
# iteration 400 / 1500: loss 9.012350
# iteration 500 / 1500: loss 9.000963
# iteration 600 / 1500: loss 8.998841
# iteration 700 / 1500: loss 8.998228
# iteration 800 / 1500: loss 8.998534
# iteration 900 / 1500: loss 8.998503
# iteration 1000 / 1500: loss 8.998528
# iteration 1100 / 1500: loss 8.998276
# iteration 1200 / 1500: loss 8.998818
# iteration 1300 / 1500: loss 8.998319
# iteration 1400 / 1500: loss 8.998599
# That took 1.037819s
# training accuracy: 0.417000
# validation accuracy: 0.421000
# iteration 0 / 1500: loss 31.668007
# iteration 100 / 1500: loss 11.028598
# iteration 200 / 1500: loss 9.180204
# iteration 300 / 1500: loss 9.014837
# iteration 400 / 1500: loss 9.000365
# iteration 500 / 1500: loss 8.999113
# iteration 600 / 1500: loss 8.998827
# iteration 700 / 1500: loss 8.998757
# iteration 800 / 1500: loss 8.999042
# iteration 900 / 1500: loss 8.998898
# iteration 1000 / 1500: loss 8.998657
# iteration 1100 / 1500: loss 8.998740
# iteration 1200 / 1500: loss 8.998825
# iteration 1300 / 1500: loss 8.998652
# iteration 1400 / 1500: loss 8.998803
# That took 0.799686s
# training accuracy: 0.413755
# validation accuracy: 0.418000
# iteration 0 / 1500: loss 39.073005
# iteration 100 / 1500: loss 10.193025
# iteration 200 / 1500: loss 9.047226
# iteration 300 / 1500: loss 9.001006
# iteration 400 / 1500: loss 8.999211
# iteration 500 / 1500: loss 8.999299
# iteration 600 / 1500: loss 8.999155
# iteration 700 / 1500: loss 8.999385
# iteration 800 / 1500: loss 8.998922
# iteration 900 / 1500: loss 8.999104
# iteration 1000 / 1500: loss 8.999040
# iteration 1100 / 1500: loss 8.999019
# iteration 1200 / 1500: loss 8.999012
# iteration 1300 / 1500: loss 8.999189
# iteration 1400 / 1500: loss 8.998990
# That took 0.794870s
# training accuracy: 0.417939
# validation accuracy: 0.418000
# iteration 0 / 1500: loss 61.414249
# iteration 100 / 1500: loss 9.179298
# iteration 200 / 1500: loss 8.999971
# iteration 300 / 1500: loss 8.999539
# iteration 400 / 1500: loss 8.999532
# iteration 500 / 1500: loss 8.999436
# iteration 600 / 1500: loss 8.999510
# iteration 700 / 1500: loss 8.999533
# iteration 800 / 1500: loss 8.999511
# iteration 900 / 1500: loss 8.999522
# iteration 1000 / 1500: loss 8.999559
# iteration 1100 / 1500: loss 8.999439
# iteration 1200 / 1500: loss 8.999463
# iteration 1300 / 1500: loss 8.999510
# iteration 1400 / 1500: loss 8.999579
# That took 0.779616s
# training accuracy: 0.410796
# validation accuracy: 0.417000
# iteration 0 / 1500: loss 15.120709
# iteration 100 / 1500: loss 12.223346
# iteration 200 / 1500: loss 10.701726
# iteration 300 / 1500: loss 9.891574
# iteration 400 / 1500: loss 9.466367
# iteration 500 / 1500: loss 9.245434
# iteration 600 / 1500: loss 9.127513
# iteration 700 / 1500: loss 9.066431
# iteration 800 / 1500: loss 9.032291
# iteration 900 / 1500: loss 9.014944
# iteration 1000 / 1500: loss 9.005584
# iteration 1100 / 1500: loss 9.001286
# iteration 1200 / 1500: loss 8.998314
# iteration 1300 / 1500: loss 8.996580
# iteration 1400 / 1500: loss 8.996702
# That took 0.880678s
# training accuracy: 0.409939
# validation accuracy: 0.422000
# iteration 0 / 1500: loss 19.327541
# iteration 100 / 1500: loss 10.915111
# iteration 200 / 1500: loss 9.352132
# iteration 300 / 1500: loss 9.064091
# iteration 400 / 1500: loss 9.010172
# iteration 500 / 1500: loss 8.999751
# iteration 600 / 1500: loss 8.998220
# iteration 700 / 1500: loss 8.998229
# iteration 800 / 1500: loss 8.997842
# iteration 900 / 1500: loss 8.997409
# iteration 1000 / 1500: loss 8.997305
# iteration 1100 / 1500: loss 8.997538
# iteration 1200 / 1500: loss 8.997646
# iteration 1300 / 1500: loss 8.997340
# iteration 1400 / 1500: loss 8.997705
# That took 1.112913s
# training accuracy: 0.416347
# validation accuracy: 0.425000
# iteration 0 / 1500: loss 22.862835
# iteration 100 / 1500: loss 10.581501
# iteration 200 / 1500: loss 9.177209
# iteration 300 / 1500: loss 9.019267
# iteration 400 / 1500: loss 9.000813
# iteration 500 / 1500: loss 8.998713
# iteration 600 / 1500: loss 8.997947
# iteration 700 / 1500: loss 8.997472
# iteration 800 / 1500: loss 8.997932
# iteration 900 / 1500: loss 8.997661
# iteration 1000 / 1500: loss 8.998011
# iteration 1100 / 1500: loss 8.998227
# iteration 1200 / 1500: loss 8.997925
# iteration 1300 / 1500: loss 8.997762
# iteration 1400 / 1500: loss 8.998126
# That took 1.070358s
# training accuracy: 0.415000
# validation accuracy: 0.421000
# iteration 0 / 1500: loss 25.511064
# iteration 100 / 1500: loss 10.156734
# iteration 200 / 1500: loss 9.079928
# iteration 300 / 1500: loss 9.004126
# iteration 400 / 1500: loss 8.998924
# iteration 500 / 1500: loss 8.998668
# iteration 600 / 1500: loss 8.998639
# iteration 700 / 1500: loss 8.998283
# iteration 800 / 1500: loss 8.998550
# iteration 900 / 1500: loss 8.998567
# iteration 1000 / 1500: loss 8.998542
# iteration 1100 / 1500: loss 8.998310
# iteration 1200 / 1500: loss 8.998622
# iteration 1300 / 1500: loss 8.998483
# iteration 1400 / 1500: loss 8.998485
# That took 1.107883s
# training accuracy: 0.413224
# validation accuracy: 0.412000
# iteration 0 / 1500: loss 31.952711
# iteration 100 / 1500: loss 9.604440
# iteration 200 / 1500: loss 9.014599
# iteration 300 / 1500: loss 8.999349
# iteration 400 / 1500: loss 8.998601
# iteration 500 / 1500: loss 8.998757
# iteration 600 / 1500: loss 8.998843
# iteration 700 / 1500: loss 8.998876
# iteration 800 / 1500: loss 8.998944
# iteration 900 / 1500: loss 8.998657
# iteration 1000 / 1500: loss 8.999105
# iteration 1100 / 1500: loss 8.998867
# iteration 1200 / 1500: loss 8.998840
# iteration 1300 / 1500: loss 8.998917
# iteration 1400 / 1500: loss 8.998823
# That took 0.850175s
# training accuracy: 0.414020
# validation accuracy: 0.427000
# iteration 0 / 1500: loss 37.540586
# iteration 100 / 1500: loss 9.220393
# iteration 200 / 1500: loss 9.000883
# iteration 300 / 1500: loss 8.999115
# iteration 400 / 1500: loss 8.998979
# iteration 500 / 1500: loss 8.999185
# iteration 600 / 1500: loss 8.999022
# iteration 700 / 1500: loss 8.998919
# iteration 800 / 1500: loss 8.999121
# iteration 900 / 1500: loss 8.998993
# iteration 1000 / 1500: loss 8.999247
# iteration 1100 / 1500: loss 8.999181
# iteration 1200 / 1500: loss 8.999249
# iteration 1300 / 1500: loss 8.999028
# iteration 1400 / 1500: loss 8.999155
# That took 0.767631s
# training accuracy: 0.411327
# validation accuracy: 0.407000
# iteration 0 / 1500: loss 61.452634
# iteration 100 / 1500: loss 9.009576
# iteration 200 / 1500: loss 8.999484
# iteration 300 / 1500: loss 8.999521
# iteration 400 / 1500: loss 8.999503
# iteration 500 / 1500: loss 8.999414
# iteration 600 / 1500: loss 8.999500
# iteration 700 / 1500: loss 8.999423
# iteration 800 / 1500: loss 8.999542
# iteration 900 / 1500: loss 8.999522
# iteration 1000 / 1500: loss 8.999525
# iteration 1100 / 1500: loss 8.999442
# iteration 1200 / 1500: loss 8.999442
# iteration 1300 / 1500: loss 8.999516
# iteration 1400 / 1500: loss 8.999534
# That took 0.775327s
# training accuracy: 0.410816
# validation accuracy: 0.426000
# iteration 0 / 1500: loss 15.746151
# iteration 100 / 1500: loss 11.575053
# iteration 200 / 1500: loss 9.978001
# iteration 300 / 1500: loss 9.373879
# iteration 400 / 1500: loss 9.140461
# iteration 500 / 1500: loss 9.051742
# iteration 600 / 1500: loss 9.015703
# iteration 700 / 1500: loss 9.002958
# iteration 800 / 1500: loss 8.998859
# iteration 900 / 1500: loss 8.997704
# iteration 1000 / 1500: loss 8.995532
# iteration 1100 / 1500: loss 8.995030
# iteration 1200 / 1500: loss 8.996029
# iteration 1300 / 1500: loss 8.996017
# iteration 1400 / 1500: loss 8.994795
# That took 0.770620s
# training accuracy: 0.415531
# validation accuracy: 0.414000
# iteration 0 / 1500: loss 20.173813
# iteration 100 / 1500: loss 10.171350
# iteration 200 / 1500: loss 9.121745
# iteration 300 / 1500: loss 9.009769
# iteration 400 / 1500: loss 8.998695
# iteration 500 / 1500: loss 8.997636
# iteration 600 / 1500: loss 8.997297
# iteration 700 / 1500: loss 8.997253
# iteration 800 / 1500: loss 8.998005
# iteration 900 / 1500: loss 8.997528
# iteration 1000 / 1500: loss 8.997662
# iteration 1100 / 1500: loss 8.998036
# iteration 1200 / 1500: loss 8.997581
# iteration 1300 / 1500: loss 8.997563
# iteration 1400 / 1500: loss 8.997150
# That took 1.055913s
# training accuracy: 0.416184
# validation accuracy: 0.426000
# iteration 0 / 1500: loss 23.138505
# iteration 100 / 1500: loss 9.778387
# iteration 200 / 1500: loss 9.040152
# iteration 300 / 1500: loss 9.000484
# iteration 400 / 1500: loss 8.998748
# iteration 500 / 1500: loss 8.998183
# iteration 600 / 1500: loss 8.997909
# iteration 700 / 1500: loss 8.998109
# iteration 800 / 1500: loss 8.997603
# iteration 900 / 1500: loss 8.997936
# iteration 1000 / 1500: loss 8.997990
# iteration 1100 / 1500: loss 8.998595
# iteration 1200 / 1500: loss 8.998310
# iteration 1300 / 1500: loss 8.997835
# iteration 1400 / 1500: loss 8.997950
# That took 1.114816s
# training accuracy: 0.413388
# validation accuracy: 0.414000
# iteration 0 / 1500: loss 26.050883
# iteration 100 / 1500: loss 9.486598
# iteration 200 / 1500: loss 9.011917
# iteration 300 / 1500: loss 8.998762
# iteration 400 / 1500: loss 8.998631
# iteration 500 / 1500: loss 8.998234
# iteration 600 / 1500: loss 8.998395
# iteration 700 / 1500: loss 8.998250
# iteration 800 / 1500: loss 8.998251
# iteration 900 / 1500: loss 8.998625
# iteration 1000 / 1500: loss 8.998223
# iteration 1100 / 1500: loss 8.998372
# iteration 1200 / 1500: loss 8.998239
# iteration 1300 / 1500: loss 8.998376
# iteration 1400 / 1500: loss 8.998534
# That took 1.092889s
# training accuracy: 0.412102
# validation accuracy: 0.400000
# iteration 0 / 1500: loss 31.207495
# iteration 100 / 1500: loss 9.171090
# iteration 200 / 1500: loss 9.000155
# iteration 300 / 1500: loss 8.998936
# iteration 400 / 1500: loss 8.998647
# iteration 500 / 1500: loss 8.998965
# iteration 600 / 1500: loss 8.998625
# iteration 700 / 1500: loss 8.998742
# iteration 800 / 1500: loss 8.998912
# iteration 900 / 1500: loss 8.998998
# iteration 1000 / 1500: loss 8.998893
# iteration 1100 / 1500: loss 8.998721
# iteration 1200 / 1500: loss 8.998893
# iteration 1300 / 1500: loss 8.998702
# iteration 1400 / 1500: loss 8.998868
# That took 1.087617s
# training accuracy: 0.416388
# validation accuracy: 0.418000
# iteration 0 / 1500: loss 41.836928
# iteration 100 / 1500: loss 9.048711
# iteration 200 / 1500: loss 8.999339
# iteration 300 / 1500: loss 8.998984
# iteration 400 / 1500: loss 8.999248
# iteration 500 / 1500: loss 8.999300
# iteration 600 / 1500: loss 8.999110
# iteration 700 / 1500: loss 8.999092
# iteration 800 / 1500: loss 8.999205
# iteration 900 / 1500: loss 8.998978
# iteration 1000 / 1500: loss 8.999013
# iteration 1100 / 1500: loss 8.999149
# iteration 1200 / 1500: loss 8.999029
# iteration 1300 / 1500: loss 8.998940
# iteration 1400 / 1500: loss 8.999221
# That took 1.129410s
# training accuracy: 0.409612
# validation accuracy: 0.414000
# iteration 0 / 1500: loss 66.005051
# iteration 100 / 1500: loss 8.999925
# iteration 200 / 1500: loss 8.999508
# iteration 300 / 1500: loss 8.999484
# iteration 400 / 1500: loss 8.999531
# iteration 500 / 1500: loss 8.999483
# iteration 600 / 1500: loss 8.999469
# iteration 700 / 1500: loss 8.999432
# iteration 800 / 1500: loss 8.999502
# iteration 900 / 1500: loss 8.999589
# iteration 1000 / 1500: loss 8.999600
# iteration 1100 / 1500: loss 8.999546
# iteration 1200 / 1500: loss 8.999472
# iteration 1300 / 1500: loss 8.999529
# iteration 1400 / 1500: loss 8.999509
# That took 1.150493s
# training accuracy: 0.410510
# validation accuracy: 0.412000
# iteration 0 / 1500: loss 15.060765
# iteration 100 / 1500: loss 10.674141
# iteration 200 / 1500: loss 9.457116
# iteration 300 / 1500: loss 9.125366
# iteration 400 / 1500: loss 9.031354
# iteration 500 / 1500: loss 9.004922
# iteration 600 / 1500: loss 8.997938
# iteration 700 / 1500: loss 8.995945
# iteration 800 / 1500: loss 8.997095
# iteration 900 / 1500: loss 8.996285
# iteration 1000 / 1500: loss 8.995082
# iteration 1100 / 1500: loss 8.995140
# iteration 1200 / 1500: loss 8.995744
# iteration 1300 / 1500: loss 8.994625
# iteration 1400 / 1500: loss 8.996224
# That took 1.089088s
# training accuracy: 0.412735
# validation accuracy: 0.409000
# iteration 0 / 1500: loss 19.902796
# iteration 100 / 1500: loss 9.364013
# iteration 200 / 1500: loss 9.009220
# iteration 300 / 1500: loss 8.998173
# iteration 400 / 1500: loss 8.997532
# iteration 500 / 1500: loss 8.997748
# iteration 600 / 1500: loss 8.997929
# iteration 700 / 1500: loss 8.997721
# iteration 800 / 1500: loss 8.997549
# iteration 900 / 1500: loss 8.996981
# iteration 1000 / 1500: loss 8.997576
# iteration 1100 / 1500: loss 8.997908
# iteration 1200 / 1500: loss 8.997424
# iteration 1300 / 1500: loss 8.997357
# iteration 1400 / 1500: loss 8.997485
# That took 0.916736s
# training accuracy: 0.409367
# validation accuracy: 0.404000
# iteration 0 / 1500: loss 23.154508
# iteration 100 / 1500: loss 9.176107
# iteration 200 / 1500: loss 9.000677
# iteration 300 / 1500: loss 8.998198
# iteration 400 / 1500: loss 8.998129
# iteration 500 / 1500: loss 8.998249
# iteration 600 / 1500: loss 8.997788
# iteration 700 / 1500: loss 8.998088
# iteration 800 / 1500: loss 8.998174
# iteration 900 / 1500: loss 8.998165
# iteration 1000 / 1500: loss 8.998379
# iteration 1100 / 1500: loss 8.998110
# iteration 1200 / 1500: loss 8.998130
# iteration 1300 / 1500: loss 8.998413
# iteration 1400 / 1500: loss 8.998084
# That took 0.818676s
# training accuracy: 0.414245
# validation accuracy: 0.417000
# iteration 0 / 1500: loss 26.169655
# iteration 100 / 1500: loss 9.078945
# iteration 200 / 1500: loss 8.998778
# iteration 300 / 1500: loss 8.998830
# iteration 400 / 1500: loss 8.998790
# iteration 500 / 1500: loss 8.998283
# iteration 600 / 1500: loss 8.998503
# iteration 700 / 1500: loss 8.998511
# iteration 800 / 1500: loss 8.998420
# iteration 900 / 1500: loss 8.998625
# iteration 1000 / 1500: loss 8.998632
# iteration 1100 / 1500: loss 8.998273
# iteration 1200 / 1500: loss 8.998474
# iteration 1300 / 1500: loss 8.998361
# iteration 1400 / 1500: loss 8.998424
# That took 0.773533s
# training accuracy: 0.409776
# validation accuracy: 0.413000
# iteration 0 / 1500: loss 31.609147
# iteration 100 / 1500: loss 9.013529
# iteration 200 / 1500: loss 8.998883
# iteration 300 / 1500: loss 8.998754
# iteration 400 / 1500: loss 8.998958
# iteration 500 / 1500: loss 8.998854
# iteration 600 / 1500: loss 8.998890
# iteration 700 / 1500: loss 8.998773
# iteration 800 / 1500: loss 8.998588
# iteration 900 / 1500: loss 8.998948
# iteration 1000 / 1500: loss 8.998722
# iteration 1100 / 1500: loss 8.998925
# iteration 1200 / 1500: loss 8.998907
# iteration 1300 / 1500: loss 8.998868
# iteration 1400 / 1500: loss 8.998702
# That took 0.788762s
# training accuracy: 0.411776
# validation accuracy: 0.409000
# iteration 0 / 1500: loss 39.017526
# iteration 100 / 1500: loss 9.000768
# iteration 200 / 1500: loss 8.999165
# iteration 300 / 1500: loss 8.999025
# iteration 400 / 1500: loss 8.999196
# iteration 500 / 1500: loss 8.999189
# iteration 600 / 1500: loss 8.999196
# iteration 700 / 1500: loss 8.999346
# iteration 800 / 1500: loss 8.999113
# iteration 900 / 1500: loss 8.999186
# iteration 1000 / 1500: loss 8.999242
# iteration 1100 / 1500: loss 8.999141
# iteration 1200 / 1500: loss 8.999140
# iteration 1300 / 1500: loss 8.999055
# iteration 1400 / 1500: loss 8.999074
# That took 1.122823s
# training accuracy: 0.414204
# validation accuracy: 0.421000
# iteration 0 / 1500: loss 61.959417
# iteration 100 / 1500: loss 8.999528
# iteration 200 / 1500: loss 8.999569
# iteration 300 / 1500: loss 8.999570
# iteration 400 / 1500: loss 8.999549
# iteration 500 / 1500: loss 8.999525
# iteration 600 / 1500: loss 8.999560
# iteration 700 / 1500: loss 8.999582
# iteration 800 / 1500: loss 8.999466
# iteration 900 / 1500: loss 8.999562
# iteration 1000 / 1500: loss 8.999508
# iteration 1100 / 1500: loss 8.999497
# iteration 1200 / 1500: loss 8.999380
# iteration 1300 / 1500: loss 8.999468
# iteration 1400 / 1500: loss 8.999534
# That took 1.095889s
# training accuracy: 0.412122
# validation accuracy: 0.419000
# iteration 0 / 1500: loss 15.194957
# iteration 100 / 1500: loss 9.893751
# iteration 200 / 1500: loss 9.126715
# iteration 300 / 1500: loss 9.015323
# iteration 400 / 1500: loss 8.997755
# iteration 500 / 1500: loss 8.994601
# iteration 600 / 1500: loss 8.995203
# iteration 700 / 1500: loss 8.994590
# iteration 800 / 1500: loss 8.996051
# iteration 900 / 1500: loss 8.994870
# iteration 1000 / 1500: loss 8.995488
# iteration 1100 / 1500: loss 8.995721
# iteration 1200 / 1500: loss 8.995668
# iteration 1300 / 1500: loss 8.994560
# iteration 1400 / 1500: loss 8.996289
# That took 1.086880s
# training accuracy: 0.415000
# validation accuracy: 0.404000
# iteration 0 / 1500: loss 19.680872
# iteration 100 / 1500: loss 9.005629
# iteration 200 / 1500: loss 8.997276
# iteration 300 / 1500: loss 8.997553
# iteration 400 / 1500: loss 8.997981
# iteration 500 / 1500: loss 8.997165
# iteration 600 / 1500: loss 8.997602
# iteration 700 / 1500: loss 8.997729
# iteration 800 / 1500: loss 8.997490
# iteration 900 / 1500: loss 8.996983
# iteration 1000 / 1500: loss 8.997365
# iteration 1100 / 1500: loss 8.997602
# iteration 1200 / 1500: loss 8.997364
# iteration 1300 / 1500: loss 8.997598
# iteration 1400 / 1500: loss 8.997600
# That took 1.091854s
# training accuracy: 0.412367
# validation accuracy: 0.417000
# iteration 0 / 1500: loss 22.846571
# iteration 100 / 1500: loss 8.999331
# iteration 200 / 1500: loss 8.998118
# iteration 300 / 1500: loss 8.997931
# iteration 400 / 1500: loss 8.998321
# iteration 500 / 1500: loss 8.998323
# iteration 600 / 1500: loss 8.998301
# iteration 700 / 1500: loss 8.998197
# iteration 800 / 1500: loss 8.998067
# iteration 900 / 1500: loss 8.997687
# iteration 1000 / 1500: loss 8.997940
# iteration 1100 / 1500: loss 8.997649
# iteration 1200 / 1500: loss 8.998019
# iteration 1300 / 1500: loss 8.998135
# iteration 1400 / 1500: loss 8.998249
# That took 0.969252s
# training accuracy: 0.411020
# validation accuracy: 0.406000
# iteration 0 / 1500: loss 27.281635
# iteration 100 / 1500: loss 8.998636
# iteration 200 / 1500: loss 8.998603
# iteration 300 / 1500: loss 8.998629
# iteration 400 / 1500: loss 8.998037
# iteration 500 / 1500: loss 8.998293
# iteration 600 / 1500: loss 8.998050
# iteration 700 / 1500: loss 8.998642
# iteration 800 / 1500: loss 8.998026
# iteration 900 / 1500: loss 8.998245
# iteration 1000 / 1500: loss 8.998513
# iteration 1100 / 1500: loss 8.998398
# iteration 1200 / 1500: loss 8.998704
# iteration 1300 / 1500: loss 8.998641
# iteration 1400 / 1500: loss 8.998535
# That took 0.803543s
# training accuracy: 0.414612
# validation accuracy: 0.427000
# iteration 0 / 1500: loss 31.008428
# iteration 100 / 1500: loss 8.999007
# iteration 200 / 1500: loss 8.999005
# iteration 300 / 1500: loss 8.999222
# iteration 400 / 1500: loss 8.998846
# iteration 500 / 1500: loss 8.998883
# iteration 600 / 1500: loss 8.998799
# iteration 700 / 1500: loss 8.998774
# iteration 800 / 1500: loss 8.998952
# iteration 900 / 1500: loss 8.998719
# iteration 1000 / 1500: loss 8.998895
# iteration 1100 / 1500: loss 8.998988
# iteration 1200 / 1500: loss 8.998869
# iteration 1300 / 1500: loss 8.998751
# iteration 1400 / 1500: loss 8.998636
# That took 0.797596s
# training accuracy: 0.413408
# validation accuracy: 0.413000
# iteration 0 / 1500: loss 37.678222
# iteration 100 / 1500: loss 8.999062
# iteration 200 / 1500: loss 8.999060
# iteration 300 / 1500: loss 8.999197
# iteration 400 / 1500: loss 8.998967
# iteration 500 / 1500: loss 8.999104
# iteration 600 / 1500: loss 8.999345
# iteration 700 / 1500: loss 8.999171
# iteration 800 / 1500: loss 8.999146
# iteration 900 / 1500: loss 8.999150
# iteration 1000 / 1500: loss 8.999044
# iteration 1100 / 1500: loss 8.999100
# iteration 1200 / 1500: loss 8.999134
# iteration 1300 / 1500: loss 8.999242
# iteration 1400 / 1500: loss 8.999072
# That took 0.785612s
# training accuracy: 0.401653
# validation accuracy: 0.392000
# iteration 0 / 1500: loss 65.973175
# iteration 100 / 1500: loss 8.999492
# iteration 200 / 1500: loss 8.999532
# iteration 300 / 1500: loss 8.999428
# iteration 400 / 1500: loss 8.999533
# iteration 500 / 1500: loss 8.999510
# iteration 600 / 1500: loss 8.999505
# iteration 700 / 1500: loss 8.999648
# iteration 800 / 1500: loss 8.999475
# iteration 900 / 1500: loss 8.999642
# iteration 1000 / 1500: loss 8.999551
# iteration 1100 / 1500: loss 8.999497
# iteration 1200 / 1500: loss 8.999576
# iteration 1300 / 1500: loss 8.999408
# iteration 1400 / 1500: loss 8.999592
# That took 0.890213s
# training accuracy: 0.401041
# validation accuracy: 0.387000
# iteration 0 / 1500: loss 14.968196
# iteration 100 / 1500: loss 9.099473
# iteration 200 / 1500: loss 8.996800
# iteration 300 / 1500: loss 8.995550
# iteration 400 / 1500: loss 8.997084
# iteration 500 / 1500: loss 8.996003
# iteration 600 / 1500: loss 8.994402
# iteration 700 / 1500: loss 8.995716
# iteration 800 / 1500: loss 8.995654
# iteration 900 / 1500: loss 8.995509
# iteration 1000 / 1500: loss 8.996031
# iteration 1100 / 1500: loss 8.996071
# iteration 1200 / 1500: loss 8.995913
# iteration 1300 / 1500: loss 8.996108
# iteration 1400 / 1500: loss 8.994915
# That took 1.094838s
# training accuracy: 0.413265
# validation accuracy: 0.411000
# iteration 0 / 1500: loss 19.793318
# iteration 100 / 1500: loss 8.997432
# iteration 200 / 1500: loss 8.997794
# iteration 300 / 1500: loss 8.997401
# iteration 400 / 1500: loss 8.997913
# iteration 500 / 1500: loss 8.997893
# iteration 600 / 1500: loss 8.997425
# iteration 700 / 1500: loss 8.997598
# iteration 800 / 1500: loss 8.997410
# iteration 900 / 1500: loss 8.997892
# iteration 1000 / 1500: loss 8.997534
# iteration 1100 / 1500: loss 8.997404
# iteration 1200 / 1500: loss 8.997393
# iteration 1300 / 1500: loss 8.996994
# iteration 1400 / 1500: loss 8.997613
# That took 1.107882s
# training accuracy: 0.409408
# validation accuracy: 0.414000
# iteration 0 / 1500: loss 22.656568
# iteration 100 / 1500: loss 8.998374
# iteration 200 / 1500: loss 8.998096
# iteration 300 / 1500: loss 8.998071
# iteration 400 / 1500: loss 8.997616
# iteration 500 / 1500: loss 8.997957
# iteration 600 / 1500: loss 8.997852
# iteration 700 / 1500: loss 8.998293
# iteration 800 / 1500: loss 8.998570
# iteration 900 / 1500: loss 8.998195
# iteration 1000 / 1500: loss 8.998188
# iteration 1100 / 1500: loss 8.997764
# iteration 1200 / 1500: loss 8.998460
# iteration 1300 / 1500: loss 8.997807
# iteration 1400 / 1500: loss 8.998401
# That took 1.080746s
# training accuracy: 0.412714
# validation accuracy: 0.415000
# iteration 0 / 1500: loss 26.596470
# iteration 100 / 1500: loss 8.998306
# iteration 200 / 1500: loss 8.998147
# iteration 300 / 1500: loss 8.998511
# iteration 400 / 1500: loss 8.998672
# iteration 500 / 1500: loss 8.998287
# iteration 600 / 1500: loss 8.998612
# iteration 700 / 1500: loss 8.998242
# iteration 800 / 1500: loss 8.998509
# iteration 900 / 1500: loss 8.998468
# iteration 1000 / 1500: loss 8.998827
# iteration 1100 / 1500: loss 8.998358
# iteration 1200 / 1500: loss 8.998198
# iteration 1300 / 1500: loss 8.998427
# iteration 1400 / 1500: loss 8.998560
# That took 1.130041s
# training accuracy: 0.405735
# validation accuracy: 0.424000
# iteration 0 / 1500: loss 32.082142
# iteration 100 / 1500: loss 8.999230
# iteration 200 / 1500: loss 8.998875
# iteration 300 / 1500: loss 8.998950
# iteration 400 / 1500: loss 8.999235
# iteration 500 / 1500: loss 8.998825
# iteration 600 / 1500: loss 8.998972
# iteration 700 / 1500: loss 8.999004
# iteration 800 / 1500: loss 8.998888
# iteration 900 / 1500: loss 8.998773
# iteration 1000 / 1500: loss 8.999015
# iteration 1100 / 1500: loss 8.998756
# iteration 1200 / 1500: loss 8.999414
# iteration 1300 / 1500: loss 8.999064
# iteration 1400 / 1500: loss 8.998872
# That took 1.111894s
# training accuracy: 0.405408
# validation accuracy: 0.408000
# iteration 0 / 1500: loss 42.947599
# iteration 100 / 1500: loss 8.999245
# iteration 200 / 1500: loss 8.999121
# iteration 300 / 1500: loss 8.999308
# iteration 400 / 1500: loss 8.999152
# iteration 500 / 1500: loss 8.999245
# iteration 600 / 1500: loss 8.998996
# iteration 700 / 1500: loss 8.999209
# iteration 800 / 1500: loss 8.999087
# iteration 900 / 1500: loss 8.999042
# iteration 1000 / 1500: loss 8.999289
# iteration 1100 / 1500: loss 8.998978
# iteration 1200 / 1500: loss 8.999051
# iteration 1300 / 1500: loss 8.999070
# iteration 1400 / 1500: loss 8.999002
# That took 0.758592s
# training accuracy: 0.387776
# validation accuracy: 0.401000
# iteration 0 / 1500: loss 63.121355
# iteration 100 / 1500: loss 8.999503
# iteration 200 / 1500: loss 8.999607
# iteration 300 / 1500: loss 8.999641
# iteration 400 / 1500: loss 8.999596
# iteration 500 / 1500: loss 8.999565
# iteration 600 / 1500: loss 8.999440
# iteration 700 / 1500: loss 8.999574
# iteration 800 / 1500: loss 8.999454
# iteration 900 / 1500: loss 8.999453
# iteration 1000 / 1500: loss 8.999529
# iteration 1100 / 1500: loss 8.999526
# iteration 1200 / 1500: loss 8.999591
# iteration 1300 / 1500: loss 8.999575
# iteration 1400 / 1500: loss 8.999517
# That took 0.774061s
# training accuracy: 0.388184
# validation accuracy: 0.401000
# iteration 0 / 1500: loss 15.205213
# iteration 100 / 1500: loss 9.004964
# iteration 200 / 1500: loss 8.995591
# iteration 300 / 1500: loss 8.994738
# iteration 400 / 1500: loss 8.994950
# iteration 500 / 1500: loss 8.995293
# iteration 600 / 1500: loss 8.995972
# iteration 700 / 1500: loss 8.995806
# iteration 800 / 1500: loss 8.995624
# iteration 900 / 1500: loss 8.995525
# iteration 1000 / 1500: loss 8.996444
# iteration 1100 / 1500: loss 8.995328
# iteration 1200 / 1500: loss 8.996557
# iteration 1300 / 1500: loss 8.995484
# iteration 1400 / 1500: loss 8.995597
# That took 0.742580s
# training accuracy: 0.412837
# validation accuracy: 0.405000
# lr 2.000000e-07 reg 4.000000e+03 train accuracy: 0.212286 val accuracy: 0.223000
# lr 2.000000e-07 reg 7.000000e+03 train accuracy: 0.375306 val accuracy: 0.361000
# lr 2.000000e-07 reg 9.000000e+03 train accuracy: 0.402592 val accuracy: 0.375000
# lr 2.000000e-07 reg 1.100000e+04 train accuracy: 0.414327 val accuracy: 0.406000
# lr 2.000000e-07 reg 1.500000e+04 train accuracy: 0.416245 val accuracy: 0.422000
# lr 2.000000e-07 reg 2.000000e+04 train accuracy: 0.413306 val accuracy: 0.415000
# lr 2.000000e-07 reg 3.500000e+04 train accuracy: 0.412898 val accuracy: 0.422000
# lr 4.000000e-07 reg 4.000000e+03 train accuracy: 0.409939 val accuracy: 0.422000
# lr 4.000000e-07 reg 7.000000e+03 train accuracy: 0.412776 val accuracy: 0.421000
# lr 4.000000e-07 reg 9.000000e+03 train accuracy: 0.410224 val accuracy: 0.407000
# lr 4.000000e-07 reg 1.100000e+04 train accuracy: 0.417000 val accuracy: 0.421000
# lr 4.000000e-07 reg 1.500000e+04 train accuracy: 0.413755 val accuracy: 0.418000
# lr 4.000000e-07 reg 2.000000e+04 train accuracy: 0.417939 val accuracy: 0.418000
# lr 4.000000e-07 reg 3.500000e+04 train accuracy: 0.410796 val accuracy: 0.417000
# lr 6.000000e-07 reg 4.000000e+03 train accuracy: 0.415531 val accuracy: 0.414000
# lr 6.000000e-07 reg 7.000000e+03 train accuracy: 0.416347 val accuracy: 0.425000
# lr 6.000000e-07 reg 9.000000e+03 train accuracy: 0.415000 val accuracy: 0.421000
# lr 6.000000e-07 reg 1.100000e+04 train accuracy: 0.413224 val accuracy: 0.412000
# lr 6.000000e-07 reg 1.500000e+04 train accuracy: 0.414020 val accuracy: 0.427000
# lr 6.000000e-07 reg 2.000000e+04 train accuracy: 0.411327 val accuracy: 0.407000
# lr 6.000000e-07 reg 3.500000e+04 train accuracy: 0.410816 val accuracy: 0.426000
# lr 8.000000e-07 reg 4.000000e+03 train accuracy: 0.412735 val accuracy: 0.409000
# lr 8.000000e-07 reg 7.000000e+03 train accuracy: 0.416184 val accuracy: 0.426000
# lr 8.000000e-07 reg 9.000000e+03 train accuracy: 0.413388 val accuracy: 0.414000
# lr 8.000000e-07 reg 1.100000e+04 train accuracy: 0.412102 val accuracy: 0.400000
# lr 8.000000e-07 reg 1.500000e+04 train accuracy: 0.416388 val accuracy: 0.418000
# lr 8.000000e-07 reg 2.000000e+04 train accuracy: 0.409612 val accuracy: 0.414000
# lr 8.000000e-07 reg 3.500000e+04 train accuracy: 0.410510 val accuracy: 0.412000
# lr 1.200000e-06 reg 4.000000e+03 train accuracy: 0.415000 val accuracy: 0.404000
# lr 1.200000e-06 reg 7.000000e+03 train accuracy: 0.409367 val accuracy: 0.404000
# lr 1.200000e-06 reg 9.000000e+03 train accuracy: 0.414245 val accuracy: 0.417000
# lr 1.200000e-06 reg 1.100000e+04 train accuracy: 0.409776 val accuracy: 0.413000
# lr 1.200000e-06 reg 1.500000e+04 train accuracy: 0.411776 val accuracy: 0.409000
# lr 1.200000e-06 reg 2.000000e+04 train accuracy: 0.414204 val accuracy: 0.421000
# lr 1.200000e-06 reg 3.500000e+04 train accuracy: 0.412122 val accuracy: 0.419000
# lr 2.500000e-06 reg 4.000000e+03 train accuracy: 0.413265 val accuracy: 0.411000
# lr 2.500000e-06 reg 7.000000e+03 train accuracy: 0.412367 val accuracy: 0.417000
# lr 2.500000e-06 reg 9.000000e+03 train accuracy: 0.411020 val accuracy: 0.406000
# lr 2.500000e-06 reg 1.100000e+04 train accuracy: 0.414612 val accuracy: 0.427000
# lr 2.500000e-06 reg 1.500000e+04 train accuracy: 0.413408 val accuracy: 0.413000
# lr 2.500000e-06 reg 2.000000e+04 train accuracy: 0.401653 val accuracy: 0.392000
# lr 2.500000e-06 reg 3.500000e+04 train accuracy: 0.401041 val accuracy: 0.387000
# lr 4.000000e-06 reg 4.000000e+03 train accuracy: 0.412837 val accuracy: 0.405000
# lr 4.000000e-06 reg 7.000000e+03 train accuracy: 0.409408 val accuracy: 0.414000
# lr 4.000000e-06 reg 9.000000e+03 train accuracy: 0.412714 val accuracy: 0.415000
# lr 4.000000e-06 reg 1.100000e+04 train accuracy: 0.405735 val accuracy: 0.424000
# lr 4.000000e-06 reg 1.500000e+04 train accuracy: 0.405408 val accuracy: 0.408000
# lr 4.000000e-06 reg 2.000000e+04 train accuracy: 0.387776 val accuracy: 0.401000
# lr 4.000000e-06 reg 3.500000e+04 train accuracy: 0.388184 val accuracy: 0.401000
# best validation accuracy achieved during cross-validation: 0.427000

# %%
# Visualize the cross-validation results
import math
x_scatter = [math.log10(x[0]) for x in results]
y_scatter = [math.log10(x[1]) for x in results]

# plot training accuracy
marker_size = 100
colors = [results[x][0] for x in results]
plt.subplot(2, 1, 1)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors,cmap = "jet")
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 training accuracy')

# plot validation accuracy
colors = [results[x][1] for x in results] # default size of markers is 20
#print("dbg1: ", colors)
plt.subplot(2, 1, 2)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors,cmap="rainbow")
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.show()

# plot validation accuracy of last few 
colors = [results[x][1] for x in results] # default size of markers is 20
indices = np.argsort(colors)[-20:]
x_scatter2 = np.array(x_scatter)[indices]
y_scatter2 = np.array(y_scatter)[indices]
colors2 = np.array(colors)[indices]

plt.subplot(2, 1, 2)
plt.scatter(x_scatter2, y_scatter2, marker_size, c=colors2,cmap = "rainbow")
plt.colorbar()

for i in range(20):
    plt.annotate(i, (x_scatter2[i], y_scatter2[i]))

plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.show()

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.425

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
# Some of them do. common misclassifications for planes for eample are objects in front of a blue background such as a ship in water or a dog on a blue surface. also cats are coomonly classified as dogs which makes sense as they probably share some similarities.

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
print(X_train_feats.shape)
# Out:
# (49000, 155)

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
import time
learning_rates = [1e-1,5e-1,1,2]
regularization_strengths = [1e-3,5e-3,1e-2,5e-2]

results = {}
best_val = -1   # The highest validation accuracy that we have seen so far.
best_new = None # The deepnet object that achieved the highest validation rate.


for l_rate in learning_rates:
  for r_strength in regularization_strengths:    
    net = TwoLayerNet(input_dim, hidden_dim, num_classes)
    tic = time.time()
    stats = net.train(X_train_feats, y_train, X_val_feats, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=l_rate, learning_rate_decay=0.95,
            reg=r_strength, verbose=True)
    toc = time.time()
    print('That took %fs' % (toc - tic))
    train_acc = stats["train_acc_history"][-1]
    print('training accuracy: %f' % train_acc)
    val_acc = stats["val_acc_history"][-1]
    print('validation accuracy: %f' % val_acc)    
    
    results[l_rate,r_strength] = [train_acc,val_acc]
    if val_acc>best_val:
      best_val = val_acc
      best_net = net

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# iteration 0 / 1000: loss 2.302593
# iteration 100 / 1000: loss 2.301974
# iteration 200 / 1000: loss 2.303004
# iteration 300 / 1000: loss 2.292603
# iteration 400 / 1000: loss 2.185360
# iteration 500 / 1000: loss 1.987503
# iteration 600 / 1000: loss 1.904076
# iteration 700 / 1000: loss 1.919861
# iteration 800 / 1000: loss 1.733089
# iteration 900 / 1000: loss 1.675383
# That took 6.099939s
# training accuracy: 0.475000
# validation accuracy: 0.413000
# iteration 0 / 1000: loss 2.302627
# iteration 100 / 1000: loss 2.302911
# iteration 200 / 1000: loss 2.303280
# iteration 300 / 1000: loss 2.301743
# iteration 400 / 1000: loss 2.294856
# iteration 500 / 1000: loss 2.231870
# iteration 600 / 1000: loss 2.165269
# iteration 700 / 1000: loss 2.129135
# iteration 800 / 1000: loss 2.097870
# iteration 900 / 1000: loss 2.000792
# That took 4.778642s
# training accuracy: 0.320000
# validation accuracy: 0.307000
# iteration 0 / 1000: loss 2.302668
# iteration 100 / 1000: loss 2.302972
# iteration 200 / 1000: loss 2.302693
# iteration 300 / 1000: loss 2.302548
# iteration 400 / 1000: loss 2.302527
# iteration 500 / 1000: loss 2.301955
# iteration 600 / 1000: loss 2.298825
# iteration 700 / 1000: loss 2.282202
# iteration 800 / 1000: loss 2.283398
# iteration 900 / 1000: loss 2.259188
# That took 5.886624s
# training accuracy: 0.265000
# validation accuracy: 0.236000
# iteration 0 / 1000: loss 2.302999
# iteration 100 / 1000: loss 2.302177
# iteration 200 / 1000: loss 2.302361
# iteration 300 / 1000: loss 2.303258
# iteration 400 / 1000: loss 2.302664
# iteration 500 / 1000: loss 2.302262
# iteration 600 / 1000: loss 2.303420
# iteration 700 / 1000: loss 2.302746
# iteration 800 / 1000: loss 2.302110
# iteration 900 / 1000: loss 2.302102
# That took 4.488453s
# training accuracy: 0.095000
# validation accuracy: 0.119000
# iteration 0 / 1000: loss 2.302593
# iteration 100 / 1000: loss 2.301014
# iteration 200 / 1000: loss 2.153319
# iteration 300 / 1000: loss 1.902482
# iteration 400 / 1000: loss 1.699199
# iteration 500 / 1000: loss 1.662444
# iteration 600 / 1000: loss 1.665417
# iteration 700 / 1000: loss 1.557917
# iteration 800 / 1000: loss 1.568298
# iteration 900 / 1000: loss 1.519706
# That took 5.934575s
# training accuracy: 0.515000
# validation accuracy: 0.497000
# iteration 0 / 1000: loss 2.302626
# iteration 100 / 1000: loss 2.302968
# iteration 200 / 1000: loss 2.291313
# iteration 300 / 1000: loss 2.195502
# iteration 400 / 1000: loss 2.053700
# iteration 500 / 1000: loss 2.074443
# iteration 600 / 1000: loss 2.025362
# iteration 700 / 1000: loss 2.017246
# iteration 800 / 1000: loss 1.997131
# iteration 900 / 1000: loss 1.975845
# That took 5.720434s
# training accuracy: 0.380000
# validation accuracy: 0.394000
# iteration 0 / 1000: loss 2.302668
# iteration 100 / 1000: loss 2.303788
# iteration 200 / 1000: loss 2.301337
# iteration 300 / 1000: loss 2.299073
# iteration 400 / 1000: loss 2.257295
# iteration 500 / 1000: loss 2.255814
# iteration 600 / 1000: loss 2.176750
# iteration 700 / 1000: loss 2.258412
# iteration 800 / 1000: loss 2.168409
# iteration 900 / 1000: loss 2.142296
# That took 6.548399s
# training accuracy: 0.305000
# validation accuracy: 0.294000
# iteration 0 / 1000: loss 2.302997
# iteration 100 / 1000: loss 2.303242
# iteration 200 / 1000: loss 2.301600
# iteration 300 / 1000: loss 2.302381
# iteration 400 / 1000: loss 2.301363
# iteration 500 / 1000: loss 2.303535
# iteration 600 / 1000: loss 2.303244
# iteration 700 / 1000: loss 2.303383
# iteration 800 / 1000: loss 2.302662
# iteration 900 / 1000: loss 2.302518
# That took 5.339767s
# training accuracy: 0.130000
# validation accuracy: 0.079000
# iteration 0 / 1000: loss 2.302593
# iteration 100 / 1000: loss 1.568293
# iteration 200 / 1000: loss 1.647078
# iteration 300 / 1000: loss 1.589841
# iteration 400 / 1000: loss 1.590041
# iteration 500 / 1000: loss 1.575377
# iteration 600 / 1000: loss 1.563032
# iteration 700 / 1000: loss 1.666296
# iteration 800 / 1000: loss 1.641688
# iteration 900 / 1000: loss 1.600531
# That took 5.905457s
# training accuracy: 0.580000
# validation accuracy: 0.483000
# iteration 0 / 1000: loss 2.302626
# iteration 100 / 1000: loss 2.118844
# iteration 200 / 1000: loss 2.041475
# iteration 300 / 1000: loss 1.958582
# iteration 400 / 1000: loss 2.054331
# iteration 500 / 1000: loss 1.933002
# iteration 600 / 1000: loss 1.964369
# iteration 700 / 1000: loss 1.967664
# iteration 800 / 1000: loss 1.974297
# iteration 900 / 1000: loss 1.958861
# That took 6.822434s
# training accuracy: 0.500000
# validation accuracy: 0.391000
# iteration 0 / 1000: loss 2.302668
# iteration 100 / 1000: loss 2.216555
# iteration 200 / 1000: loss 2.129661
# iteration 300 / 1000: loss 2.162204
# iteration 400 / 1000: loss 2.201182
# iteration 500 / 1000: loss 2.158257
# iteration 600 / 1000: loss 2.112003
# iteration 700 / 1000: loss 2.180576
# iteration 800 / 1000: loss 2.148590
# iteration 900 / 1000: loss 2.185420
# That took 5.586759s
# training accuracy: 0.365000
# validation accuracy: 0.287000
# iteration 0 / 1000: loss 2.302997
# iteration 100 / 1000: loss 2.302738
# iteration 200 / 1000: loss 2.303295
# iteration 300 / 1000: loss 2.300927
# iteration 400 / 1000: loss 2.304170
# iteration 500 / 1000: loss 2.302331
# iteration 600 / 1000: loss 2.309763
# iteration 700 / 1000: loss 2.300725
# iteration 800 / 1000: loss 2.300209
# iteration 900 / 1000: loss 2.301841
# That took 5.241208s
# training accuracy: 0.120000
# validation accuracy: 0.105000
# iteration 0 / 1000: loss 2.302593
# iteration 100 / 1000: loss 1.701680
# iteration 200 / 1000: loss 1.708612
# iteration 300 / 1000: loss 1.753541
# iteration 400 / 1000: loss 1.625988
# iteration 500 / 1000: loss 1.652416
# iteration 600 / 1000: loss 1.721721
# iteration 700 / 1000: loss 1.652256
# iteration 800 / 1000: loss 1.611545
# iteration 900 / 1000: loss 1.645228
# That took 5.947662s
# training accuracy: 0.655000
# validation accuracy: 0.473000
# iteration 0 / 1000: loss 2.302626
# iteration 100 / 1000: loss 2.068628
# iteration 200 / 1000: loss 2.089180
# iteration 300 / 1000: loss 2.044006
# iteration 400 / 1000: loss 2.080917
# iteration 500 / 1000: loss 2.053832
# iteration 600 / 1000: loss 1.970712
# iteration 700 / 1000: loss 2.073987
# iteration 800 / 1000: loss 2.077395
# iteration 900 / 1000: loss 1.986200
# That took 5.447993s
# training accuracy: 0.435000
# validation accuracy: 0.367000
# iteration 0 / 1000: loss 2.302668
# iteration 100 / 1000: loss 2.208732
# iteration 200 / 1000: loss 2.158387
# iteration 300 / 1000: loss 2.145734
# iteration 400 / 1000: loss 2.244467
# iteration 500 / 1000: loss 2.253663
# iteration 600 / 1000: loss 2.200840
# iteration 700 / 1000: loss 2.153705
# iteration 800 / 1000: loss 2.147943
# iteration 900 / 1000: loss 2.213125
# That took 5.548918s
# training accuracy: 0.370000
# validation accuracy: 0.276000
# iteration 0 / 1000: loss 2.302994
# iteration 100 / 1000: loss 2.305235
# iteration 200 / 1000: loss 2.299625
# iteration 300 / 1000: loss 2.304917
# iteration 400 / 1000: loss 2.302723
# iteration 500 / 1000: loss 2.301167
# iteration 600 / 1000: loss 2.302733
# iteration 700 / 1000: loss 2.310661
# iteration 800 / 1000: loss 2.300767
# iteration 900 / 1000: loss 2.308931
# That took 7.321592s
# training accuracy: 0.140000
# validation accuracy: 0.113000
# lr 5.000000e-02 reg 1.000000e-02 train accuracy: 0.475000 val accuracy: 0.413000
# lr 5.000000e-02 reg 5.000000e-02 train accuracy: 0.320000 val accuracy: 0.307000
# lr 5.000000e-02 reg 1.000000e-01 train accuracy: 0.265000 val accuracy: 0.236000
# lr 5.000000e-02 reg 5.000000e-01 train accuracy: 0.095000 val accuracy: 0.119000
# lr 1.000000e-01 reg 1.000000e-02 train accuracy: 0.515000 val accuracy: 0.497000
# lr 1.000000e-01 reg 5.000000e-02 train accuracy: 0.380000 val accuracy: 0.394000
# lr 1.000000e-01 reg 1.000000e-01 train accuracy: 0.305000 val accuracy: 0.294000
# lr 1.000000e-01 reg 5.000000e-01 train accuracy: 0.130000 val accuracy: 0.079000
# lr 5.000000e-01 reg 1.000000e-02 train accuracy: 0.580000 val accuracy: 0.483000
# lr 5.000000e-01 reg 5.000000e-02 train accuracy: 0.500000 val accuracy: 0.391000
# lr 5.000000e-01 reg 1.000000e-01 train accuracy: 0.365000 val accuracy: 0.287000
# lr 5.000000e-01 reg 5.000000e-01 train accuracy: 0.120000 val accuracy: 0.105000
# lr 1.000000e+00 reg 1.000000e-02 train accuracy: 0.655000 val accuracy: 0.473000
# lr 1.000000e+00 reg 5.000000e-02 train accuracy: 0.435000 val accuracy: 0.367000
# lr 1.000000e+00 reg 1.000000e-01 train accuracy: 0.370000 val accuracy: 0.276000
# lr 1.000000e+00 reg 5.000000e-01 train accuracy: 0.140000 val accuracy: 0.113000

# %%
# Visualize the cross-validation results
import math
x_scatter = [math.log10(x[0]) for x in results]
y_scatter = [math.log10(x[1]) for x in results]

#x_scatter = [x[0]*10000 for x in results]
#y_scatter = [x[1] for x in results]

# plot training accuracy
marker_size = 100
colors = [results[x][0] for x in results]
plt.subplot(2, 1, 1)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors,cmap = "brg")
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 training accuracy')

# plot validation accuracy
colors = [results[x][1] for x in results] # default size of markers is 20
plt.subplot(2, 1, 2)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors,cmap = "rainbow")
plt.colorbar()

for i in range(len(results)):
    plt.annotate(i, (x_scatter[i], y_scatter[i]))

plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.show()

'''
# plot validation accuracy of last few 
colors = [results[x][1] for x in results] # default size of markers is 20
plt.subplot(2, 1, 2)
plt.scatter(x_scatter[-8:], y_scatter[-8:], marker_size, c=colors[-8:],cmap = "rainbow")
plt.colorbar()

for i in range(len(results)-8,len(results)):
    plt.annotate(i, (x_scatter[i], y_scatter[i]))

plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.show()
'''
# Out:
# '\n# plot validation accuracy of last few \ncolors = [results[x][1] for x in results] # default size of markers is 20\nplt.subplot(2, 1, 2)\nplt.scatter(x_scatter[-8:], y_scatter[-8:], marker_size, c=colors[-8:],cmap = "rainbow")\nplt.colorbar()\n\nfor i in range(len(results)-8,len(results)):\n    plt.annotate(i, (x_scatter[i], y_scatter[i]))\n\nplt.xlabel(\'log learning rate\')\nplt.ylabel(\'log regularization strength\')\nplt.title(\'CIFAR-10 validation accuracy\')\nplt.show()\n'

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.

test_acc = (net.predict(X_test_feats) == y_test).mean()
print(test_acc)
# Out:
# 0.112

# %% [markdown]
# # Bonus: Design your own features!
#
# You have seen that simple image features can improve classification performance. So far we have tried HOG and color histograms, but other types of features may be able to achieve even better classification performance.
#
# For bonus points, design and implement a new type of feature and use it for image classification on CIFAR-10. Explain how your feature works and why you expect it to be useful for image classification. Implement it in this notebook, cross-validate any hyperparameters, and compare its performance to the HOG + Color histogram baseline.

# %% [markdown]
# # Bonus: Do something extra!
# Use the material and code we have presented in this assignment to do something interesting. Was there another question we should have asked? Did any cool ideas pop into your head as you were working on the assignment? This is your chance to show off!
