# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.368505
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** The loss function is -log(softmax prob of true class). At initialisation the softmax prob should be equal to 1/C where C is the number of classes. C =10 in this case, ergo: -log(0.1).

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: -0.488669 analytic: -0.488669, relative error: 6.221193e-08
# numerical: -1.522954 analytic: -1.522954, relative error: 1.015400e-08
# numerical: -3.471011 analytic: -3.471011, relative error: 1.815640e-08
# numerical: -3.136626 analytic: -3.136626, relative error: 1.406849e-08
# numerical: 0.880175 analytic: 0.880175, relative error: 2.228397e-08
# numerical: 1.607046 analytic: 1.607046, relative error: 3.938164e-08
# numerical: -0.260296 analytic: -0.260296, relative error: 1.134419e-08
# numerical: 1.453419 analytic: 1.453419, relative error: 2.756339e-08
# numerical: 1.181681 analytic: 1.181681, relative error: 4.075785e-08
# numerical: -2.050110 analytic: -2.050110, relative error: 7.461049e-09
# numerical: -5.249091 analytic: -5.249091, relative error: 1.880468e-09
# numerical: 1.080784 analytic: 1.080784, relative error: 4.527243e-08
# numerical: -1.765840 analytic: -1.765840, relative error: 1.074530e-08
# numerical: 2.682142 analytic: 2.682142, relative error: 2.811033e-08
# numerical: -2.405926 analytic: -2.405926, relative error: 6.609671e-09
# numerical: -0.135268 analytic: -0.135268, relative error: 7.096873e-08
# numerical: 3.227299 analytic: 3.227299, relative error: 1.088659e-08
# numerical: -3.601564 analytic: -3.601563, relative error: 5.848620e-09
# numerical: 1.851688 analytic: 1.851688, relative error: 2.229364e-08
# numerical: 0.685424 analytic: 0.685424, relative error: 9.202649e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.368505e+00 computed in 0.123626s
# vectorized loss: 2.368505e+00 computed in 0.004992s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [9e-8,1.25e-7,2e-7,3e-7]
regularization_strengths = [1.8e4,1.4e4,1.1e4,9e3]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
for l_rate in learning_rates:
  for r_strength in regularization_strengths:
    softmax = Softmax()
    tic = time.time()
    loss_hist = softmax.train(X_train, y_train, learning_rate=l_rate, reg=r_strength,
                      num_iters=1500, verbose=True)
    toc = time.time()
    print('That took %fs' % (toc - tic))
    y_train_pred = softmax.predict(X_train)
    train_acc = np.mean(y_train == y_train_pred)
    print('training accuracy: %f' % train_acc)
    y_val_pred = softmax.predict(X_val)
    val_acc = np.mean(y_val == y_val_pred)
    print('validation accuracy: %f' % val_acc)
    results[l_rate,r_strength] = [train_acc,val_acc]
    if val_acc>best_val:
      best_val = val_acc
      best_softmax = softmax
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 1500: loss 561.845348
# iteration 100 / 1500: loss 293.050495
# iteration 200 / 1500: loss 153.691116
# iteration 300 / 1500: loss 81.174286
# iteration 400 / 1500: loss 43.234595
# iteration 500 / 1500: loss 23.566347
# iteration 600 / 1500: loss 13.288759
# iteration 700 / 1500: loss 7.923803
# iteration 800 / 1500: loss 5.048219
# iteration 900 / 1500: loss 3.654143
# iteration 1000 / 1500: loss 2.904095
# iteration 1100 / 1500: loss 2.507435
# iteration 1200 / 1500: loss 2.269503
# iteration 1300 / 1500: loss 2.164560
# iteration 1400 / 1500: loss 2.084994
# That took 12.949365s
# training accuracy: 0.342592
# validation accuracy: 0.350000
# iteration 0 / 1500: loss 435.411649
# iteration 100 / 1500: loss 262.442107
# iteration 200 / 1500: loss 158.800667
# iteration 300 / 1500: loss 96.291818
# iteration 400 / 1500: loss 58.815197
# iteration 500 / 1500: loss 36.271009
# iteration 600 / 1500: loss 22.656757
# iteration 700 / 1500: loss 14.474986
# iteration 800 / 1500: loss 9.497771
# iteration 900 / 1500: loss 6.595202
# iteration 1000 / 1500: loss 4.776870
# iteration 1100 / 1500: loss 3.700969
# iteration 1200 / 1500: loss 3.075724
# iteration 1300 / 1500: loss 2.597850
# iteration 1400 / 1500: loss 2.354216
# That took 13.513122s
# training accuracy: 0.347857
# validation accuracy: 0.356000
# iteration 0 / 1500: loss 343.307434
# iteration 100 / 1500: loss 229.870448
# iteration 200 / 1500: loss 155.052113
# iteration 300 / 1500: loss 104.778151
# iteration 400 / 1500: loss 70.878857
# iteration 500 / 1500: loss 48.411606
# iteration 600 / 1500: loss 33.052240
# iteration 700 / 1500: loss 22.972455
# iteration 800 / 1500: loss 16.122492
# iteration 900 / 1500: loss 11.529223
# iteration 1000 / 1500: loss 8.318408
# iteration 1100 / 1500: loss 6.237629
# iteration 1200 / 1500: loss 4.886816
# iteration 1300 / 1500: loss 3.875417
# iteration 1400 / 1500: loss 3.320585
# That took 13.846842s
# training accuracy: 0.351429
# validation accuracy: 0.375000
# iteration 0 / 1500: loss 282.431077
# iteration 100 / 1500: loss 202.782027
# iteration 200 / 1500: loss 146.543370
# iteration 300 / 1500: loss 106.256775
# iteration 400 / 1500: loss 77.232261
# iteration 500 / 1500: loss 56.296527
# iteration 600 / 1500: loss 41.200630
# iteration 700 / 1500: loss 30.301578
# iteration 800 / 1500: loss 22.360087
# iteration 900 / 1500: loss 16.699169
# iteration 1000 / 1500: loss 12.632146
# iteration 1100 / 1500: loss 9.629652
# iteration 1200 / 1500: loss 7.515862
# iteration 1300 / 1500: loss 5.979987
# iteration 1400 / 1500: loss 4.919303
# That took 12.616002s
# training accuracy: 0.351980
# validation accuracy: 0.351000
# iteration 0 / 1500: loss 551.605778
# iteration 100 / 1500: loss 223.962573
# iteration 200 / 1500: loss 91.722546
# iteration 300 / 1500: loss 38.350922
# iteration 400 / 1500: loss 16.766522
# iteration 500 / 1500: loss 7.980934
# iteration 600 / 1500: loss 4.466865
# iteration 700 / 1500: loss 3.040067
# iteration 800 / 1500: loss 2.373351
# iteration 900 / 1500: loss 2.223751
# iteration 1000 / 1500: loss 2.175781
# iteration 1100 / 1500: loss 2.035794
# iteration 1200 / 1500: loss 2.113944
# iteration 1300 / 1500: loss 2.042858
# iteration 1400 / 1500: loss 2.042558
# That took 12.814627s
# training accuracy: 0.337102
# validation accuracy: 0.348000
# iteration 0 / 1500: loss 442.014862
# iteration 100 / 1500: loss 219.025029
# iteration 200 / 1500: loss 109.237520
# iteration 300 / 1500: loss 54.960009
# iteration 400 / 1500: loss 28.237173
# iteration 500 / 1500: loss 15.039590
# iteration 600 / 1500: loss 8.452795
# iteration 700 / 1500: loss 5.168993
# iteration 800 / 1500: loss 3.673460
# iteration 900 / 1500: loss 2.821994
# iteration 1000 / 1500: loss 2.477642
# iteration 1100 / 1500: loss 2.224128
# iteration 1200 / 1500: loss 2.159010
# iteration 1300 / 1500: loss 2.086867
# iteration 1400 / 1500: loss 2.057003
# That took 12.235080s
# training accuracy: 0.348694
# validation accuracy: 0.359000
# iteration 0 / 1500: loss 343.068363
# iteration 100 / 1500: loss 197.469239
# iteration 200 / 1500: loss 114.358773
# iteration 300 / 1500: loss 66.455401
# iteration 400 / 1500: loss 39.008076
# iteration 500 / 1500: loss 23.366479
# iteration 600 / 1500: loss 14.243130
# iteration 700 / 1500: loss 9.088604
# iteration 800 / 1500: loss 6.088302
# iteration 900 / 1500: loss 4.357579
# iteration 1000 / 1500: loss 3.324408
# iteration 1100 / 1500: loss 2.739021
# iteration 1200 / 1500: loss 2.469679
# iteration 1300 / 1500: loss 2.278322
# iteration 1400 / 1500: loss 2.142380
# That took 11.748103s
# training accuracy: 0.360367
# validation accuracy: 0.376000
# iteration 0 / 1500: loss 283.837102
# iteration 100 / 1500: loss 179.603974
# iteration 200 / 1500: loss 114.532016
# iteration 300 / 1500: loss 73.515013
# iteration 400 / 1500: loss 47.617914
# iteration 500 / 1500: loss 30.953613
# iteration 600 / 1500: loss 20.240554
# iteration 700 / 1500: loss 13.677458
# iteration 800 / 1500: loss 9.515447
# iteration 900 / 1500: loss 6.716560
# iteration 1000 / 1500: loss 5.027412
# iteration 1100 / 1500: loss 3.853073
# iteration 1200 / 1500: loss 3.231652
# iteration 1300 / 1500: loss 2.758641
# iteration 1400 / 1500: loss 2.509237
# That took 11.398781s
# training accuracy: 0.358776
# validation accuracy: 0.372000
# iteration 0 / 1500: loss 555.891932
# iteration 100 / 1500: loss 131.709725
# iteration 200 / 1500: loss 32.385247
# iteration 300 / 1500: loss 9.249480
# iteration 400 / 1500: loss 3.780922
# iteration 500 / 1500: loss 2.509036
# iteration 600 / 1500: loss 2.137758
# iteration 700 / 1500: loss 2.012367
# iteration 800 / 1500: loss 2.056762
# iteration 900 / 1500: loss 2.057374
# iteration 1000 / 1500: loss 2.079483
# iteration 1100 / 1500: loss 2.064133
# iteration 1200 / 1500: loss 2.019596
# iteration 1300 / 1500: loss 2.101676
# iteration 1400 / 1500: loss 2.039842
# That took 10.942254s
# training accuracy: 0.339735
# validation accuracy: 0.355000
# iteration 0 / 1500: loss 438.257162
# iteration 100 / 1500: loss 142.563371
# iteration 200 / 1500: loss 47.401401
# iteration 300 / 1500: loss 16.724068
# iteration 400 / 1500: loss 6.875069
# iteration 500 / 1500: loss 3.521351
# iteration 600 / 1500: loss 2.504774
# iteration 700 / 1500: loss 2.228548
# iteration 800 / 1500: loss 2.105905
# iteration 900 / 1500: loss 2.049313
# iteration 1000 / 1500: loss 1.971586
# iteration 1100 / 1500: loss 2.040870
# iteration 1200 / 1500: loss 2.053382
# iteration 1300 / 1500: loss 2.052956
# iteration 1400 / 1500: loss 1.999443
# That took 11.007570s
# training accuracy: 0.343265
# validation accuracy: 0.355000
# iteration 0 / 1500: loss 344.949954
# iteration 100 / 1500: loss 142.548705
# iteration 200 / 1500: loss 59.908490
# iteration 300 / 1500: loss 25.784206
# iteration 400 / 1500: loss 11.787756
# iteration 500 / 1500: loss 6.103709
# iteration 600 / 1500: loss 3.721829
# iteration 700 / 1500: loss 2.699830
# iteration 800 / 1500: loss 2.268105
# iteration 900 / 1500: loss 2.136084
# iteration 1000 / 1500: loss 2.047926
# iteration 1100 / 1500: loss 2.051284
# iteration 1200 / 1500: loss 1.975956
# iteration 1300 / 1500: loss 2.055447
# iteration 1400 / 1500: loss 2.059917
# That took 10.249329s
# training accuracy: 0.353020
# validation accuracy: 0.366000
# iteration 0 / 1500: loss 282.305216
# iteration 100 / 1500: loss 137.010196
# iteration 200 / 1500: loss 67.237931
# iteration 300 / 1500: loss 33.654646
# iteration 400 / 1500: loss 17.312004
# iteration 500 / 1500: loss 9.438687
# iteration 600 / 1500: loss 5.653785
# iteration 700 / 1500: loss 3.746688
# iteration 800 / 1500: loss 2.813759
# iteration 900 / 1500: loss 2.370187
# iteration 1000 / 1500: loss 2.153805
# iteration 1100 / 1500: loss 2.163660
# iteration 1200 / 1500: loss 2.129888
# iteration 1300 / 1500: loss 1.966157
# iteration 1400 / 1500: loss 2.017959
# That took 10.874424s
# training accuracy: 0.359020
# validation accuracy: 0.374000
# iteration 0 / 1500: loss 553.730813
# iteration 100 / 1500: loss 64.194659
# iteration 200 / 1500: loss 9.149742
# iteration 300 / 1500: loss 2.852273
# iteration 400 / 1500: loss 2.155414
# iteration 500 / 1500: loss 2.065612
# iteration 600 / 1500: loss 2.079074
# iteration 700 / 1500: loss 2.032754
# iteration 800 / 1500: loss 2.033108
# iteration 900 / 1500: loss 2.002140
# iteration 1000 / 1500: loss 2.096732
# iteration 1100 / 1500: loss 1.993181
# iteration 1200 / 1500: loss 2.033425
# iteration 1300 / 1500: loss 2.076633
# iteration 1400 / 1500: loss 2.041412
# That took 11.034272s
# training accuracy: 0.345776
# validation accuracy: 0.348000
# iteration 0 / 1500: loss 434.357856
# iteration 100 / 1500: loss 81.028927
# iteration 200 / 1500: loss 16.593451
# iteration 300 / 1500: loss 4.755658
# iteration 400 / 1500: loss 2.542496
# iteration 500 / 1500: loss 2.138194
# iteration 600 / 1500: loss 2.088056
# iteration 700 / 1500: loss 2.082135
# iteration 800 / 1500: loss 1.974469
# iteration 900 / 1500: loss 2.074930
# iteration 1000 / 1500: loss 2.032544
# iteration 1100 / 1500: loss 2.054965
# iteration 1200 / 1500: loss 2.016675
# iteration 1300 / 1500: loss 2.033781
# iteration 1400 / 1500: loss 2.042747
# That took 10.943626s
# training accuracy: 0.346347
# validation accuracy: 0.352000
# iteration 0 / 1500: loss 338.815007
# iteration 100 / 1500: loss 90.589086
# iteration 200 / 1500: loss 25.386569
# iteration 300 / 1500: loss 8.133498
# iteration 400 / 1500: loss 3.662629
# iteration 500 / 1500: loss 2.428303
# iteration 600 / 1500: loss 2.077599
# iteration 700 / 1500: loss 2.051045
# iteration 800 / 1500: loss 2.042845
# iteration 900 / 1500: loss 1.981218
# iteration 1000 / 1500: loss 2.012015
# iteration 1100 / 1500: loss 1.991390
# iteration 1200 / 1500: loss 2.034904
# iteration 1300 / 1500: loss 1.936841
# iteration 1400 / 1500: loss 1.928605
# That took 10.896351s
# training accuracy: 0.351122
# validation accuracy: 0.350000
# iteration 0 / 1500: loss 286.421665
# iteration 100 / 1500: loss 96.826782
# iteration 200 / 1500: loss 33.906429
# iteration 300 / 1500: loss 12.735438
# iteration 400 / 1500: loss 5.593281
# iteration 500 / 1500: loss 3.241599
# iteration 600 / 1500: loss 2.363020
# iteration 700 / 1500: loss 2.098563
# iteration 800 / 1500: loss 2.067743
# iteration 900 / 1500: loss 1.993695
# iteration 1000 / 1500: loss 1.958862
# iteration 1100 / 1500: loss 1.998228
# iteration 1200 / 1500: loss 1.901582
# iteration 1300 / 1500: loss 1.988380
# iteration 1400 / 1500: loss 2.003813
# That took 10.943660s
# training accuracy: 0.359388
# validation accuracy: 0.369000
# lr 9.000000e-08 reg 9.000000e+03 train accuracy: 0.351980 val accuracy: 0.351000
# lr 9.000000e-08 reg 1.100000e+04 train accuracy: 0.351429 val accuracy: 0.375000
# lr 9.000000e-08 reg 1.400000e+04 train accuracy: 0.347857 val accuracy: 0.356000
# lr 9.000000e-08 reg 1.800000e+04 train accuracy: 0.342592 val accuracy: 0.350000
# lr 1.250000e-07 reg 9.000000e+03 train accuracy: 0.358776 val accuracy: 0.372000
# lr 1.250000e-07 reg 1.100000e+04 train accuracy: 0.360367 val accuracy: 0.376000
# lr 1.250000e-07 reg 1.400000e+04 train accuracy: 0.348694 val accuracy: 0.359000
# lr 1.250000e-07 reg 1.800000e+04 train accuracy: 0.337102 val accuracy: 0.348000
# lr 2.000000e-07 reg 9.000000e+03 train accuracy: 0.359020 val accuracy: 0.374000
# lr 2.000000e-07 reg 1.100000e+04 train accuracy: 0.353020 val accuracy: 0.366000
# lr 2.000000e-07 reg 1.400000e+04 train accuracy: 0.343265 val accuracy: 0.355000
# lr 2.000000e-07 reg 1.800000e+04 train accuracy: 0.339735 val accuracy: 0.355000
# lr 3.000000e-07 reg 9.000000e+03 train accuracy: 0.359388 val accuracy: 0.369000
# lr 3.000000e-07 reg 1.100000e+04 train accuracy: 0.351122 val accuracy: 0.350000
# lr 3.000000e-07 reg 1.400000e+04 train accuracy: 0.346347 val accuracy: 0.352000
# lr 3.000000e-07 reg 1.800000e+04 train accuracy: 0.345776 val accuracy: 0.348000
# best validation accuracy achieved during cross-validation: 0.376000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.362000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
